# %% [markdown]
# # Quiz — Charts Practice
#
# Five tasks of increasing difficulty. Each section contains:
# - **Task** — what to build and what requirements to meet
#
# - **Solution** — placeholder for your solution.
#
# You are encouraged to use LLMs to solve this quiz.
#
# We will use the **Iris** dataset as an example. Iris is very famous dataset, widely used in machine learning teaching. Check the image belowe:
#
# ![alt text](./iris.png "Iris")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

iris = sns.load_dataset('iris')
iris.head()

# %% [markdown]
# ---
# ## Task 1 — Count plot: how many samples per species?
#
# **Task:** Using seaborn, create a bar chart that shows the number of flowers
# in the `iris` dataset for each species. Give each species bar a distinct colour.
# Add the title *"Number of samples per species"* and label both axes.

# %% [markdown]
# ---
# ## Task 2 — KDE plot: petal length distribution by species
#
# **Task:** On a single chart, draw a filled Kernel Density Estimate of `petal_length`
# for each species simultaneously. Use semi-transparent fills so overlapping curves
# remain readable. Add a title and x-axis label.

# %% [markdown]
# ---
# ## Task 3 — Box plot + strip plot overlay: petal width per species
#
# **Task:** Create a box plot of `petal_width` grouped by species. On the same axes,
# overlay a strip plot so that individual data points are visible as small,
# semi-transparent black dots. Add a title and axis labels.
#
# *Hint: call both `sns.boxplot` and `sns.stripplot` on the same figure before
# calling `plt.show()`.*

# %% [markdown]
# ---
# ## Task 4 — Multi-panel violin plots: all four features at once
#
# **Task:** Create a figure with **4 side-by-side subplots** (1 row, 4 columns) —
# one violin plot per numeric feature (`sepal_length`, `sepal_width`,
# `petal_length`, `petal_width`). Each violin should:
# - be grouped by species
# - display an inner box plot (`inner='box'`)
# - use the feature name (formatted nicely) as its subplot title
#
# Add the overall figure title *"Distribution of all features by species"*.

# %% [markdown]
# ---
# ## Task 5 — Scatter plot with per-species linear regression lines
#
# **Task:** Create a scatter plot of `sepal_length` (x-axis) vs `petal_length`
# (y-axis). Colour each species differently. For **each species independently**,
# compute a linear regression line using `np.polyfit` and draw it over the
# scatter. Include the regression equation *y = ax + b* (2 decimal places)
# for each species in the legend.
#
# *Hint: use `iris.groupby('species')` to iterate over species subsets.*
